# %%
import os
import pandas as pd
import requests

# Import API key
key = os.getenv("API-KEY")

# %%
# Import cleaned news dataset
path = "static/data/locations_dates.csv"
df = pd.read_csv(path, converters={"keywords": eval})
df
# Out:
#          nid                     glocation    pub_date  year     month  \
# 0          2                     Louisiana  2015-01-01  2015   January
# 1          3                 United States  2015-01-01  2015   January
# 2          5                 Boston (Mass)  2015-01-01  2015   January
# 3          6                 Killeen (Tex)  2015-01-01  2015   January
# 4         11  East Village (Manhattan, NY)  2015-01-01  2015   January
# ...      ...                           ...         ...   ...       ...
# 16283  50563                 Denver (Colo)  2015-11-13  2015  November
# 16284  50564     Acadia National Park (Me)  2015-11-13  2015  November
# 16285  50570         San Francisco (Calif)  2015-11-13  2015  November
# 16286  50571                New York State  2015-11-13  2015  November
# 16287  50572                 Wichita (Kan)  2015-11-13  2015  November
#
#         weekday
# 0      Thursday
# 1      Thursday
# 2      Thursday
# 3      Thursday
# 4      Thursday
# ...         ...
# 16283    Friday
# 16284    Friday
# 16285    Friday
# 16286    Friday
# 16287    Friday
#
# [16288 rows x 6 columns]

# %%
unique_gloc = df['glocation'].unique().tolist()
.tolist()
# Out:
# ['Louisiana',
#  'United States',
#  'Boston (Mass)',
#  'Killeen (Tex)',
#  'East Village (Manhattan, NY)',
#  'Naples (Fla)',
#  'Europe',
#  'Japan',
#  'Dagestan (Russia)',
#  'Turkey',
#  'Las Cruces (NM)',
#  'Peachtree City (Ga)',
#  'Virginia',
#  'Pennsylvania',
#  'ANTARCTIC REGIONS',
#  'New Zealand',
#  'Kentucky',
#  'Michigan',
#  'Colorado',
#  'Florida',
#  'Nebraska',
#  'Cape Canaveral (Fla)',
#  'Vernon (Vt)',
#  'Las Vegas (Nev)',
#  'France',
#  'Gilbert (Ariz)',
#  'Ferguson (Mo)',
#  'Quebec Province (Canada)',
#  'Indonesia',
#  'Iceland',
#  'Botswana',
#  'Cambridge (Mass)',
#  'Wisconsin',
#  'California',
#  'ARGENTINA',
#  'Illinois',
#  'Mission District (San Francisco, Calif)',
#  'Guantanamo Bay Naval Base (Cuba)',
#  'Great Britain',
#  'Portugal',
#  'Worcester (Mass)',
#  'Houston (Tex)',
#  'New York City',
#  'El Paso (Tex)',
#  'Atlanta (Ga)',
#  'Moab (Utah)',
#  'Washington (DC)',
#  'San Francisco (Calif)',
#  'Greece',
#  'New England States (US)',
#  'South Carolina',
#  'Texas',
#  'North Korea',
#  'China',
#  'Nantucket Sound (Mass)',
#  'Mississippi',
#  'Massachusetts',
#  'Oklahoma',
#  'South Korea',
#  'Rhode Island',
#  'Hong Kong',
#  'Spain',
#  'Vermont',
#  'Detroit (Mich)',
#  'London (England)',
#  'Phoenix (Ariz)',
#  'Georgia',
#  'Cleveland (Ohio)',
#  'Liberia',
#  'Ohio',
#  'Kansas',
#  'Canada',
#  'West Virginia',
#  'New York State',
#  'Colorado Springs (Colo)',
#  'Bermuda',
#  'Baltimore (Md)',
#  'Seattle (Wash)',
#  'Tennessee',
#  'Hobbs (NM)',
#  'Middle East',
#  'Kenya',
#  'Hyattsville (Md)',
#  'Nashville (Tenn)',
#  'Philadelphia (Pa)',
#  'Silicon Valley (Calif)',
#  'Italy',
#  'AMSTERDAM (NETHERLANDS)',
#  'Dublin (Ireland)',
#  'Charlottesville (Va)',
#  'Washington (State)',
#  'Russia',
#  'Puerto Rico',
#  'South Sudan',
#  'ALBUQUERQUE (NM)',
#  'Aurora (Colo)',
#  'Yemen',
#  'ALABAMA',
#  'Brooklyn (NYC)',
#  'Paris (France)',
#  'Switzerland',
#  'New Jersey',
#  'Roswell (NM)',
#  'Ector County (Tex)',
#  'India',
#  'Germany',
#  'Malaysia',
#  'Iran',
#  'Durham (NC)',
#  'Luxembourg',
#  'Canary Islands',
#  'ARIZONA',
#  'La Ciotat (France)',
#  'Cuba',
#  'Maine',
#  'West Hollywood (Calif)',
#  'Hawaii',
#  'Delaware',
#  'Miami (Fla)',
#  'Boys Town (Neb)',
#  'Vail (Colo)',
#  'Panama',
#  'Midland (Tex)',
#  'Columbia (SC)',
#  'Manhattan (NYC)',
#  'Denmark',
#  'Davos (Switzerland)',
#  'Sweden',
#  'ARKANSAS',
#  'Montclair (NJ)',
#  'Montana',
#  'Long Island (NY)',
#  'Owens Valley (Calif)',
#  'Madeira (Portugal)',
#  'Israel',
#  'Moscow (Russia)',
#  'Orange County (Calif)',
#  'AFRICA',
#  'Los Angeles (Calif)',
#  'Boise (Idaho)',
#  'Iowa',
#  'Salt Lake City (Utah)',
#  'Nevada',
#  'Saudi Arabia',
#  'Charleston (SC)',
#  'Fort Hood (Tex)',
#  'South Dakota',
#  'Belgium',
#  'ALASKA',
#  'New Mexico',
#  'Mojave Desert (Calif)',
#  'Ireland',
#  'San Diego (Calif)',
#  'Utah',
#  'Ukraine',
#  'Rock Hill (SC)',
#  'ARCTIC NATIONAL WILDLIFE REFUGE',
#  'Iraq',
#  'Atlantic Ocean',
#  'Nantucket (Mass)',
#  'Red Hook (Brooklyn, NY)',
#  'Indiana',
#  'Singapore',
#  'Palo Alto (Calif)',
#  'Gulf of Mexico',
#  'Hyannis (Mass)',
#  'Poland',
#  'Somerville (Mass)',
#  'Chicago (Ill)',
#  'Fort Worth (Tex)',
#  'San Geronimo (Calif)',
#  'Beijing (China)',
#  'Zurich (Switzerland)',
#  'Greenland',
#  'Wyoming',
#  'Australia',
#  'North Sea',
#  'Brussels (Belgium)',
#  'Wilmington (Del)',
#  'Pasadena (Calif)',
#  'Syria',
#  'Lake Superior',
#  'Cambodia',
#  'Toronto (Ontario)',
#  'Montgomery (Ala)',
#  'Frankfurt (Germany)',
#  'Brazil',
#  'Indianapolis (Ind)',
#  'Maryland',
#  'Malibu (Calif)',
#  'Vietnam',
#  'Jennings (Mo)',
#  'ANCHORAGE (ALASKA)',
#  'East Coast (US)',
#  'Delhi (India)',
#  'St Louis (Mo)',
#  'Chelsea (Manhattan, NY)',
#  'Oaxaca (Mexico)',
#  'Missouri',
#  'Chapel Hill (NC)',
#  'Stephenville (Tex)',
#  'North Carolina',
#  'Yarnell (Ariz)',
#  'Oregon',
#  'Kansas City (Kan)',
#  'Columbus (Ohio)',
#  'Copenhagen (Denmark)',
#  'Pasco (Wash)',
#  'Caribbean Area',
#  'Beverly Hills (Calif)',
#  'San Joaquin-Sacramento River Delta (Calif)',
#  'Mexico',
#  'North Dakota',
#  'Netherlands',
#  'Cremona (Italy)',
#  'Far East, South and Southeast Asia and Pacific Areas',
#  'Sentosa Cove (Singapore)',
#  'Bangladesh',
#  'Pittsburgh (Pa)',
#  'Key West (Fla)',
#  'United Arab Emirates',
#  'Austria',
#  'Bakken Shale Field (ND)',
#  'Northern Ireland',
#  'Minneapolis (Minn)',
#  'El Salvador',
#  'Nova Scotia (Canada)',
#  'AFGHANISTAN',
#  'Falkland Islands',
#  'Cincinnati (Ohio)',
#  'Oxnard (Calif)',
#  'Sanford (Fla)',
#  'Palm Springs (Calif)',
#  'South Africa',
#  'Mountain View (Calif)',
#  'San Francisco Bay Area (Calif)',
#  'Tyrone (Mo)',
#  'Chattanooga (Tenn)',
#  'Acushnet River (Mass)',
#  'Barcelona (Spain)',
#  'Hermosa Beach (Calif)',
#  'Abu Dhabi (United Arab Emirates)',
#  'Wall Street (Manhattan, NY)',
#  'Dallas (Tex)',
#  'Bergholz (Ohio)',
#  'North America',
#  'Kyushu (Japan)',
#  'Lynchburg (Va)',
#  'Suez Canal',
#  'Old Westbury (NY)',
#  'Pacific Ocean',
#  'Venice (Calif)',
#  'Colombia',
#  'Mississippi River',
#  'Egypt',
#  'Ontario (Canada)',
#  'Richmond (Calif)',
#  'Selma (Ala)',
#  'Madison (Wis)',
#  'Boykin (Ala)',
#  'Sierra Leone',
#  'APPALACHIAN REGION',
#  'Gulf Coast (US)',
#  'Edinburgh (Scotland)',
#  'Greenwood (Miss)',
#  'Chamblee (Ga)',
#  'Wilmington (NC)',
#  'Channel Islands (Calif)',
#  'Trenton (NJ)',
#  'Wichita (Kan)',
#  'Queens (NYC)',
#  'Atacama Desert',
#  'New Hampshire',
#  'ARCTIC REGIONS',
#  'Cheyenne (Wyo)',
#  'Minot (ND)',
#  'ANDORRA',
#  'Missoula (Mont)',
#  'Sierra Nevada Region (US)',
#  'Newport Beach (Calif)',
#  'Bronx (NYC)',
#  'Dubai (United Arab Emirates)',
#  'Sydney (Australia)',
#  'St Petersburg (Russia)',
#  'Cook County (Ill)',
#  'Monroe (Conn)',
#  'Napa (Calif)',
#  'USSR (Former Soviet Union)',
#  'Tokyo (Japan)',
#  'Nice (France)',
#  'Southern States (US)',
#  'New Orleans (La)',
#  'Minnesota',
#  'Libya',
#  'AMAZON RIVER BASIN',
#  'Santa Fe (NM)',
#  'Great Lakes',
#  'Chile',
#  'Marysville (Calif)',
#  'Savannah (Ga)',
#  'Huntington Beach (Calif)',
#  'Lake Huron',
#  'Oxford (Miss)',
#  'Meatpacking District (Manhattan, NY)',
#  'Providence (RI)',
#  'Scott County (Ind)',
#  'Gujarat State (India)',
#  'Panama City Beach (Fla)',
#  'French Alps',
#  'Austin (Ind)',
#  'Phnom Penh (Cambodia)',
#  'Western States (US)',
#  'High Line (Manhattan, NY)',
#  'Flatiron District (Manhattan, NY)',
#  'Fort Meade (Md)',
#  'Longmont (Colo)',
#  'Louisville (Ky)',
#  'Butte (Mont)',
#  'White Sands Missile Range (NM)',
#  'Central Valley (Calif)',
#  'Wake County (NC)',
#  'Chernobyl (Ukraine)',
#  'Fort Lauderdale (Fla)',
#  'Southwestern States (US)',
#  'Newark (NJ)',
#  'North Charleston (SC)',
#  'SoHo (Manhattan, NY)',
#  'Slovakia',
#  'Philippines',
#  'Chechnya (Russia)',
#  'Burgundy (France)',
#  'Guangzhou (China)',
#  'Appomattox Court House National Historical Park (Va)',
#  'San Bernardino (Calif)',
#  'San Bernardino County (Calif)',
#  'Carlsbad (Calif)',
#  'Elephant Butte (NM)',
#  'Klamath (Calif)',
#  'New Haven (Conn)',
#  'Tulsa (Okla)',
#  'Maumee (Ohio)',
#  'Rocky Mountains',
#  'Lindstrom (Minn)',
#  'Nigeria',
#  'Tuskegee (Ala)',
#  'Raccoon River (Iowa)',
#  'Oklahoma City (Okla)',
#  'Eureka Springs (Ark)',
#  'Keene (NH)',
#  'Shetland Islands (Scotland)',
#  'Ivory Coast',
#  'Idaho',
#  'Oak Ridge (Tenn)',
#  'Milan (Italy)',
#  'Everglades National Park',
#  'Berlin (Germany)',
#  'Bridgeport (Conn)',
#  'Indian Ocean',
#  'Parma (Mo)',
#  'St Louis County (Mo)',
#  'Riga (Latvia)',
#  'Everglades (Fla)',
#  'Mount Everest',
#  'Knoxville (Tenn)',
#  'Miami Beach (Fla)',
#  'Isle Royale National Park (Mich)',
#  'Winston-Salem (NC)',
#  'Western Europe',
#  'Carlstadt (NJ)',
#  'Beatrice (Neb)',
#  'Pine Ridge Indian Reservation (SD)',
#  'Mississippi River-Gulf Outlet',
#  'Garland (Tex)',
#  'Waterloo (Belgium)',
#  'Bangalore (India)',
#  'Marcellus Shale',
#  'West Orange (NJ)',
#  'Nepal',
#  'Rapid City (SD)',
#  'Bentonville (Ark)',
#  'Carlsbad (NM)',
#  'ARCTIC OCEAN',
#  'Fredericksburg (Va)',
#  'Azerbaijan',
#  'Hattiesburg (Miss)',
#  'Guyana',
#  'Haiti',
#  'Finland',
#  'Yosemite National Park (Calif)',
#  'Menomonee Falls (Wis)',
#  'Burgess Shale (Canada)',
#  'Chukchi Sea',
#  'Western Cape (South Africa)',
#  'Mystic (Conn)',
#  'Northeastern States (US)',
#  'Piermont (NY)',
#  'British Columbia (Canada)',
#  'Spuyten Duyvil (Bronx, NY)',
#  'Chautauqua (NY)',
#  'Uruguay',
#  'Gibraltar',
#  'Asheville (NC)',
#  'Spring Branch (Tex)',
#  'Waco (Tex)',
#  'Galesburg (Ill)',
#  'Camden (NJ)',
#  'Tibet',
#  'Scandinavia',
#  'Connecticut',
#  'Trout Run (Frederick County, Md)',
#  'Benghazi (Libya)',
#  'Sacramento (Calif)',
#  'Sintra (Portugal)',
#  'Wood Lake (Neb)',
#  'Tangelo Park (Fla)',
#  'Vatican City',
#  'Yangtze River (China)',
#  'Brownsville (Tex)',
#  'Youngstown (Ohio)',
#  'Dresden (Germany)',
#  'Wimberley (Tex)',
#  'Denver (Colo)',
#  'Poconos (Pa)',
#  'Saratoga (NY)',
#  'Central Asia',
#  'Hollywood (Calif)',
#  'Cumberland River',
#  'Hirado (Japan)',
#  'Broward County (Fla)',
#  'Himalayas',
#  'Roosevelt Island (Manhattan, NY)',
#  'Yakima River Valley (Wash)',
#  'Springfield (Mo)',
#  'Orlando (Fla)',
#  'Scotland',
#  'Harlem (Manhattan, NY)',
#  'Virgin Islands (Great Britain)',
#  'Tallahassee (Fla)',
#  'Marshall Islands',
#  'Sao Paulo (Brazil)',
#  'Senatobia (Miss)',
#  'Seoul (South Korea)',
#  'Yorkville (Ill)',
#  'Port Townsend (Wash)',
#  'Upper East Side (Manhattan, NY)',
#  'Jerusalem (Israel)',
#  'Peshawar (Pakistan)',
#  'Jersey City (NJ)',
#  'McKinney (Tex)',
#  'Wilsonville (Ore)',
#  'Austin (Tex)',
#  'England',
#  'Roosevelt, Franklin D, Four Freedoms Park (Manhattan, NY)',
#  'Dayton (Ohio)',
#  'AMES (IOWA)',
#  'Uganda',
#  'Park City (Utah)',
#  'Central Park (Manhattan, NY)',
#  'Bryant Park (Manhattan, NY)',
#  'Spokane (Wash)',
#  'Dilley (Tex)',
#  'Athens (Greece)',
#  'Maricopa County (Ariz)',
#  'Kansas City (Mo)',
#  'Tuscany (Italy)',
#  'Burbank (Calif)',
#  'Bozeman (Mont)',
#  'Sahara Desert',
#  'Blytheville (Ark)',
#  'Shanghai (China)',
#  'Memphis (Tenn)',
#  'Coachella Valley (Calif)',
#  'Cannes (France)',
#  'Elk River (W Va)',
#  'South China Sea',
#  'Provincetown (Mass)',
#  'ALEXANDRIA (VA)',
#  'South Burlington (Vt)',
#  'Lancashire (England)',
#  'Lithuania',
#  'Cyprus',
#  'George Washington Bridge',
#  'Bar Harbor (Me)',
#  'Shenzhen (China)',
#  'Greeleyville (SC)',
#  'Havana (Cuba)',
#  'Portland (Me)',
#  'Times Square and 42nd Street (Manhattan, NY)',
#  'Vancouver (British Columbia)',
#  'Burlington (Vt)',
#  'Cupertino (Calif)',
#  'Richmond (Va)',
#  'Iowa City (Iowa)',
#  'Isle of Man',
#  'Palm Beach (Fla)',
#  'Scituate (Mass)',
#  'Kennebunkport (Me)',
#  'Waco Mammoth National Monument (Waco, Tex)',
#  'Tacoma (Wash)',
#  "Martha's Vineyard (Mass)",
#  'Birmingham (Ala)',
#  'Jardines de la Reina (Cuba)',
#  'Aspen (Colo)',
#  'Van Meter (Iowa)',
#  'Newport News (Va)',
#  'San Juan (Puerto Rico)',
#  'Orland (Calif)',
#  'Christoval (Tex)',
#  'Qatar',
#  'Laramie (Wyo)',
#  'Gardena (Calif)',
#  'El Reno (Okla)',
#  'Morocco',
#  'Waller County (Tex)',
#  'Des Moines (Iowa)',
#  'Hixson (Tenn)',
#  'Harris County (Tex)',
#  'Latin America',
#  'Macedonia',
#  'Buffalo (NY)',
#  'Mumbai (India)',
#  'Berkeley (Calif)',
#  'Bahama Islands',
#  'Cape Town (South Africa)',
#  'Munich (Germany)',
#  'Laredo (Tex)',
#  'Hamptons (NY)',
#  'Block Island (RI)',
#  'Dugway Proving Ground (Utah)',
#  'Lafayette (La)',
#  'Ecuador',
#  'Yellowstone National Park',
#  'Flatbush (Brooklyn, NY)',
#  'Central America',
#  'Ethiopia',
#  'Hispaniola',
#  'Milwaukee (Wis)',
#  'Jamestown (Va)',
#  'Sarasota (Fla)',
#  'AMHERST (MASS)',
#  'Hwange National Park (Zimbabwe)',
#  'Santa Cruz (Calif)',
#  'Riverton (Wyo)',
#  'Santander (Spain)',
#  'Hague (Netherlands)',
#  'Southeastern States (US)',
#  'ABU GHRAIB (IRAQ)',
#  'Hudson Yards (Manhattan, NY)',
#  'Sudan',
#  'Pacific Palisades (Calif)',
#  'Staten Island (NYC)',
#  'Pocomoke City (Md)',
#  'St Lawrence Island (Alaska)',
#  'Charlotte (NC)',
#  'Covington (Ky)',
#  'South America',
#  'Faribault (Minn)',
#  'Nicodemus (Kan)',
#  'Phoenix Mountains Preserve (Phoenix, Ariz)',
#  'Seneca (SC)',
#  'San Joaquin Valley (Calif)',
#  'Animas River (Colo-NM)',
#  'ARLINGTON (TEX)',
#  'Albemarle Sound',
#  'Pacific Northwestern States (US)',
#  'Carlton (Wis)',
#  'Yonkers (NY)',
#  'Bayreuth (Germany)',
#  'Buenos Aires (Argentina)',
#  'Pebble Beach (Calif)',
#  'Boston Harbor (Mass)',
#  'Karnes City (Tex)',
#  'Starkville (Miss)',
#  'Madrid (Spain)',
#  'Bergen (Norway)',
#  'Bangkok (Thailand)',
#  'Fort Benning (Ga)',
#  'Concord (NH)',
#  'Westchester County (NY)',
#  'Tajikistan',
#  'Kazakhstan',
#  'Mobile (Ala)',
#  'Carson City (Nev)',
#  'Greenville (SC)',
#  'Long Branch (NJ)',
#  'Heard Island and McDonald Islands',
#  'Mauna Kea Volcano (Hawaii)',
#  'Mount Tambora (Indonesia)',
#  'New Brunswick (NJ)',
#  'Roanoke (Va)',
#  'Prague (Czech Republic)',
#  'Rowan County (Ky)',
#  'Baxter State Park (Me)',
#  'Jackson Hole (Wyo)',
#  'Black Rock Desert (Nev)',
#  'Overland Park (Kan)',
#  'Denali National Park (Alaska)',
#  'San Antonio (Tex)',
#  'Hillsboro (Mo)',
#  'Ithaca (NY)',
#  'Mount Denali (Alaska)',
#  'Marin County (Calif)',
#  'Fox Lake (Ill)',
#  'Basel (Switzerland)',
#  'Springfield (Mass)',
#  'Stockholm (Sweden)',
#  'Santa Clara County (Calif)',
#  'Estes Park (Colo)',
#  'Attwater Prairie Chicken National Wildlife Refuge (Tex)',
#  'Bowdon (Ga)',
#  'Peoria (Ill)',
#  'St Paul (Minn)',
#  'ALBERTA (CANADA)',
#  'Williamsburg (Brooklyn, NY)',
#  'Sinjar (Iraq)',
#  'Shanksville (PA)',
#  'Somalia',
#  'Inglewood (Calif)',
#  'Venezuela',
#  'Fairfax County (Va)',
#  'Reno (Nev)',
#  'Marble Falls (Tex)',
#  'Papua New Guinea',
#  'Sonoma County (Calif)',
#  'Congo, Democratic Republic of (Congo-Kinshasa)',
#  'Pearl Harbor (Hawaii)',
#  'Middletown (Calif)',
#  'Portland (Ore)',
#  'Grand Canyon (Ariz)',
#  'Simi Valley (Calif)',
#  'East Harlem (Manhattan, NY)',
#  'Irving (Tex)',
#  'Coney Island (Brooklyn, NY)',
#  'Spring (Tex)',
#  'Stockton (Calif)',
#  'Mackinac Island (Mich)',
#  'Ventura (Calif)',
#  'Newton (Mass)',
#  'East Selma (Ala)',
#  'Archie Carr National Wildlife Refuge (Fla)',
#  'Reston (Va)',
#  'Upper West Side (Manhattan, NY)',
#  'Brasilia (Brazil)',
#  'Winsted (Conn)',
#  'Columbine (Colo)',
#  'Carmel (Calif)',
#  'Ohio River',
#  'Burlington (NJ)',
#  'Roseburg (Ore)',
#  'Davie (Fla)',
#  'Oakland (Calif)',
#  'St Vincent',
#  'Nicaragua',
#  'Tuxedo (NY)',
#  'Corvallis (Ore)',
#  'Flint (Mich)',
#  'Flagstaff (Ariz)',
#  'Ghana',
#  'Guinea',
#  'Hopkinton (Mass)',
#  'Belarus',
#  'Boulder (Colo)',
#  'Jacksonville (Fla)',
#  'Southern Ocean',
#  'Fort Myers (Fla)',
#  'Perry County (Ala)',
#  'Doha (Qatar)',
#  'Lake Iseo (Italy)',
#  'Norway',
#  'Verbier (Switzerland)',
#  'Mediterranean Sea',
#  'Jakarta (Indonesia)',
#  'Fifth Avenue (Manhattan, NY)',
#  'Great Salt Lake (Utah)',
#  'New Delhi (India)',
#  'Beringia',
#  'Fort Bragg (NC)',
#  'Downtown Brooklyn (Brooklyn, NY)',
#  'Henderson (Nev)',
#  'Abbottabad (Pakistan)',
#  'Gulf of Maine',
#  'Honolulu (Hawaii)',
#  'Sinai Peninsula (Egypt)',
#  'Omaha (Neb)',
#  'Palatine (Ill)',
#  'Point Reyes (Calif)',
#  'Pagedale (Mo)',
#  'Canon City (Colo)',
#  'Inkster (Mich)',
#  'Columbia (Mo)',
#  "Prince George's County (Md)",
#  'Pangaea',
#  'AKRON (OHIO)',
#  'Hawaii (The Big Island)',
#  'Melbourne (Australia)',
#  'Palm Beach Gardens (Fla)',
#  'Boca Raton (Fla)',
#  'Cork (Ireland)',
#  'ALAMEDA COUNTY (CALIF)',
#  'AMARILLO (TEX)',
#  'Chestertown (Md)',
#  'Downey (Calif)',
#  'Santa Monica (Calif)',
#  'Bolivia',
#  'Santa Rosa (Calif)',
#  'Xinjiang (China)',
#  'Siberia',
#  'Anatolia',
#  'Thailand',
#  'Bern (Switzerland)',
#  'Zagreb (Croatia)',
#  'West Bank',
#  'Macau',
#  'Honduras',
#  'Cape Cod (Mass)',
#  'Rio de Janeiro (Brazil)',
#  'Rwanda',
#  'Macon (Ga)',
#  'East Broadway (Manhattan, NY)',
#  'New York Metropolitan Area',
#  'Clinton Hill (Brooklyn, NY)',
#  'North Pole',
#  'Hvidovre (Denmark)',
#  'Sun City (Ariz)',
#  'Beirut (Lebanon)',
#  'Jordan',
#  'Raleigh (NC)',
#  'North Adams (Mass)',
#  'Riverside (Calif)',
#  'Taiwan',
#  'Highland Park (Ill)',
#  'Lewiston (Me)',
#  'Valdosta (Ga)',
#  'Auburn Hills (Mich)',
#  'Denton (Tex)',
#  'San Jose (Calif)',
#  'Galapagos Islands',
#  'Uzbekistan',
#  'Murfreesboro (Tenn)',
#  'York (England)',
#  'Pakistan',
#  'Raqqa (Syria)',
#  'Manchester (NH)',
#  'Zimbabwe',
#  'Nashua (NH)',
#  'Stamford (Conn)',
#  'Grand Rapids (Mich)',
#  'White Plains (NY)',
#  'Edison (NJ)',
#  'Bagram Air Base (Afghanistan)',
#  'Financial District (Manhattan, NY)',
#  'Pocatello (Idaho)',
#  'Lebanon',
#  'Forest Hills (Queens, NY)',
#  'Polynesia',
#  'Tarrant County (Tex)',
#  'Plainsboro (NJ)',
#  'Meramec River (Missouri)',
#  'Marfa (Tex)',
#  'Majorca (Spain)',
#  'Midtown Area (Manhattan, NY)',
#  'Borough Park (Brooklyn, NY)',
#  'Cayman Islands',
#  'Princeton (NJ)',
#  'Malheur National Wildlife Refuge (Oregon)',
#  'Zhejiang Province (China)',
#  'Greenwich Village (Manhattan, NY)',
#  'Harrisonburg (Va)',
#  'Herald Square (Manhattan, NY)',
#  'Middletown (RI)',
#  'Montgomery County (Pa)',
#  'Redondo Beach (Calif)',
#  'Otisville (NY)',
#  'Frankstown Township (Pa)',
#  'Baton Rouge (La)',
#  'Miami-Dade County (Fla)',
#  'Fairfield (Conn)',
#  'Oman',
#  'Hanover (NH)',
#  'Klamath River',
#  'Brittany (France)',
#  'Kuwait',
#  'Vandenberg Air Force Base (Calif)',
#  'Burns (Ore)',
#  'Patagonia (Argentina)',
#  'Marion (Ala)',
#  'Guangdong Province (China)',
#  'Dongguan (China)',
#  'Wasilla (Alaska)',
#  'Hildale (Utah)',
#  'Baghdad (Iraq)',
#  'Santa Ana (Calif)',
#  'Oakland County (Mich)',
#  'East Cleveland (Ohio)',
#  'Tiananmen Square (Beijing)',
#  'Auburn (Ala)',
#  'Manitowoc (Wis)',
#  'La Jolla (Calif)',
#  'Harrisburg (Pa)',
#  'Springfield (Ill)',
#  'Chappaqua (NY)',
#  'Williston (ND)',
#  'Westport (Conn)',
#  'Rancho Mirage (Calif)',
#  'Sebring (Ohio)',
#  'AIKEN (SC)',
#  'Asbury Park (NJ)',
#  'El Cajon (Calif)',
#  'Compton (Calif)',
#  'Abingdon (Md)',
#  'Orangeburg (SC)',
#  'McAllen (Tex)',
#  'Glendale (Ariz)',
#  'Peru',
#  'Tucson (Ariz)',
#  'Hailey (Idaho)',
#  'AMERICAN SAMOA',
#  'West Palm Beach (Fla)',
#  'San Fernando Valley (Calif)',
#  'Monroeville (Ala)',
#  'Kalamazoo (Mich)',
#  'Rio Grande Valley (Tex)',
#  'Death Valley National Park',
#  'Fort Leavenworth (Kan)',
#  'Fairfax (Va)',
#  'Martins Beach (Calif)',
#  'Virginia Beach (Va)',
#  'Gulfport (Miss)',
#  'Lower East Side (Manhattan, NY)',
#  'Hesston (Kan)',
#  'Dominican Republic',
#  'Oahu (Hawaii)',
#  'ANAHEIM (CALIF)',
#  'Johnstown (Pa)',
#  'Niger Delta (Nigeria)',
#  'St Petersburg (Fla)',
#  'Sagaponack (NY)',
#  'Midwestern States (US)',
#  'Malawi',
#  'Greensboro (NC)',
#  'Abraham Lake (Alberta, Canada)',
#  'Garden State Parkway (NJ)',
#  'Wilkinsburg (Pa)',
#  'Fayetteville (NC)',
#  'Florida Keys',
#  'Northern Mariana Islands',
#  'Tampa (Fla)',
#  'Quonset Point (RI)',
#  'Flushing (Queens, NY)',
#  'Melanesia',
#  'Farmers Branch (Tex)',
#  'Seneca Lake (NY)',
#  'ALGERIA',
#  'Everett (Wash)',
#  'Fall River (Mass)',
#  'Saskatchewan (Canada)',
#  'Virgin Islands (US)',
#  'Battery Park City (Manhattan, NY)',
#  'Purchase (NY)',
#  'Elkhart (Ind)',
#  'Fargo (ND)',
#  'Kigali (Rwanda)',
#  'Brooklyn Navy Yard (Brooklyn, NY)',
#  'Vernal (Utah)',
#  'Bethpage (NY)',
#  'Pueblo (Colo)',
#  'Marietta (Ohio)',
#  'Brighton Beach (Brooklyn, NY)',
#  'Yaroslavl (Russia)',
#  'Selinsgrove (Pa)',
#  'Hawthorne (Calif)',
#  'My Lai (Vietnam)',
#  'Kew Gardens (Queens, NY)',
#  'Binghamton (NY)',
#  'Dearborn (Mich)',
#  'Washington Square Park (Manhattan, NY)',
#  'Palos Verdes (Calif)',
#  'Windham (NH)',
#  'Rodeo Drive (Beverly Hills, Calif)',
#  'Rome (Italy)',
#  'Jackson (Miss)',
#  'Redwood National and State Parks (Calif)',
#  'ARLINGTON (VA)',
#  'Clarksville (Tenn)',
#  'Sri Lanka',
#  'Newtown (Conn)',
#  'Tijuana (Mexico)',
#  'Inyo National Forest (Calif)',
#  'Appling (Ga)',
#  'Tanzania',
#  'Paterson (NJ)',
#  'Costa Mesa (Calif)',
#  'Caspian Sea',
#  'Iwo Jima (Japan)',
#  'ANN ARBOR (MICH)',
#  'McDowell County (W Va)',
#  'Manitoba (Canada)',
#  'Columbia River (Pacific Northwest)',
#  'Newport (Vt)',
#  'West (Tex)',
#  'Fresno (Calif)',
#  'Santa Barbara (Calif)',
#  'Chester (Conn)',
#  'Port St Lucie (Fla)',
#  'Montreal (Quebec)',
#  'Cape Verde',
#  'Dandong (China)',
#  'Lake Mead',
#  'Ross (ND)',
#  'Geneva (Switzerland)',
#  'Quabbin Reservoir (Mass)',
#  'East Hampton (NY)',
#  'Brazos River (Tex)',
#  'Cleveland (Miss)',
#  'Granada (Spain)',
#  'Flores (Indonesia)',
#  'Hardwick (Vt)',
#  'Grand Canyon National Park',
#  'Bowery (Manhattan, NY)',
#  'Northampton (Mass)',
#  'Petra (Jordan)',
#  'Key Biscayne (Fla)',
#  'Lake Michigan',
#  'Petaluma (Calif)',
#  'Cambridge (England)',
#  'Lake Tahoe (Nev)',
#  'Katy (Tex)',
#  'Silk Road (Ancient Trade Route)',
#  'Andrews Air Force Base (Md)',
#  'Thousand Islands',
#  'Williston (Fla)',
#  'Portsmouth (NH)',
#  'Lake Okeechobee (Fla)',
#  'Rye (NY)',
#  'Brewster (Mass)',
#  'Telluride (Colo)',
#  'Jamaica (West Indies)',
#  'Tupelo (Miss)',
#  'Monessen (Pa)',
#  'Atlantic City (NJ)',
#  'Gottesman, Irving (1930-2016)',
#  'Falcon Heights (Minn)',
#  'Manhasset (NY)',
#  'Serbia',
#  'Hayward (Calif)',
#  'Little Rock (Ark)',
#  'Norfolk (Va)',
#  'Union Square (Manhattan, NY)',
#  'AIX-EN-PROVENCE (FRANCE)',
#  'Huntington (NY)',
#  'Pacific Crest Trail',
#  'Taipei (Taiwan)',
#  'Lahore (Pakistan)',
#  'Sevnica (Slovenia)',
#  'Panama Canal and Canal Zone',
#  'Mauritania',
#  'Sausalito (Calif)',
#  'North Miami (Fla)',
#  'Fountain (Colo)',
#  'Delaware River',
#  'Scranton (Pa)',
#  'Laos',
#  'Ellicott City (Md)',
#  'Crimea (Ukraine)',
#  'Brooklyn Heights (Brooklyn, NY)',
#  'Randallstown (Md)',
#  'Punta Gorda (Fla)',
#  'Herat (Afghanistan)',
#  'Pine Bluff (Ark)',
#  'Phoenix Islands (Kiribati)',
#  'Wynwood (Miami, Fla)',
#  'Bavaria (Germany)',
#  'Johannesburg (South Africa)',
#  'Potomac River',
#  'Midway Atoll',
#  'Kenai Peninsula (Alaska)',
#  'Cape Cod National Seashore',
#  'Biloxi (Miss)',
#  'Durant (Miss)',
#  'Dudley (Mass)',
#  'Gowanus (Brooklyn, NY)',
#  'East Chicago (Ind)',
#  'Dearborn County (Ind)',
#  'Tasmania (Australia)',
#  'Frederick (Md)',
#  'Myanmar',
#  'Redwood City (Calif)',
#  'Portsmouth (Va)',
#  'Standing Rock Sioux Reservation (ND-SD)',
#  'Ellis Island (NYC)',
#  'Carlisle (England)',
#  'Madagascar',
#  'Glendale (Calif)',
#  'Fort Pierce (Fla)',
#  'Marine Corps Recruit Depot Parris Island (SC)',
#  'Norwalk (Ohio)',
#  'Venice (Italy)',
#  'Seaside Park (NJ)',
#  'APPALACHIAN TRAIL',
#  'St Cloud (Minn)',
#  ...]

# %%
# def get_geocode(place_string):
    # for i in range(len(df)):
        place_string = df['glocation'][16284]
        r = requests.get("https://maps.googleapis.com/maps/api/geocode/json", params)

        # return the request's result

# %%
# def get_geocode_cached(place_string):
#     if place_string in database:
#         return place_string's result column
#     else:
#         result = get_geocode(place_string)
#         load place_string and result into the database
#         return result
