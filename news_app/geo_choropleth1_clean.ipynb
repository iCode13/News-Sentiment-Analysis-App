# %% [markdown]
# # **Location Data Prep for Choropleth Maps**

# %% [markdown]
# ### Setup dependencies.

# %%
import pandas as pd
import datetime

# Import cleaned news dataset
path = "../data/files/headlines.csv"
df = pd.read_csv(path, converters={"keywords": eval})
df.head()
# Out:
#                                             abstract document_type  \
# 0  Farhad Manjoo picks four products from 2014 th...       article
# 1  Representative Steve Scalise’s effort to expla...       article
# 2  Minimum wage increases go into effect in 20 st...       article
# 3  A new job title — chief of laboratory safety —...       article
# 4  Lawyers for Dzhokhar Tsarnaev, the defendant i...       article
#
#                                             headline  \
# 0  Standouts in Tech: Drones, Virtual Reality, In...
# 1  Much of David Duke’s ’91 Campaign Is Now in Lo...
# 2  States’ Minimum Wages Rise, Helping Millions o...
# 3       New C.D.C. Job Overseeing Laboratory Safety
# 4   Massachusetts: New Effort to Move Bombings Trial
#
#                                             keywords  \
# 0  [{'name': 'organizations', 'value': 'Oculus VR...
# 1  [{'name': 'persons', 'value': 'Alford, Jeremy'...
# 2  [{'name': 'subject', 'value': 'Minimum Wage', ...
# 3  [{'name': 'persons', 'value': 'McNeil, Donald ...
# 4  [{'name': 'subject', 'value': 'Boston Marathon...
#
#                                       lead_paragraph news_desk    pub_date  \
# 0  LOTS of cool new technology products come out ...  Business  2015-01-01
# 1  BATON ROUGE, La. — David Duke seems a figure f...  National  2015-01-01
# 2  For some low-wage workers, everyday tasks like...  Business  2015-01-01
# 3  A new job title — chief of laboratory safety —...  National  2015-01-01
# 4  Lawyers for Dzhokhar Tsarnaev, the defendant i...  National  2015-01-01
#
#    section_name                                            snippet  \
# 0    Technology  Farhad Manjoo picks four products from 2014 th...
# 1          U.S.  Representative Steve Scalise’s effort to expla...
# 2  Business Day  Minimum wage increases go into effect in 20 st...
# 3        Health  A new job title — chief of laboratory safety —...
# 4          U.S.  Lawyers for Dzhokhar Tsarnaev, the defendant i...
#
#   type_of_material  word_count
# 0             News         824
# 1             News        1293
# 2             News        1017
# 3            Brief         129
# 4            Brief         145

# %% [markdown]
# ### Add 'nid' (news id) field

# %%
nid_list = []
for i in range(len(df)):
    nid = int(i+1)
    nid_list.append(nid)
df.insert(loc=0, column='nid', value=nid_list)
df
# Out:
#          nid                                           abstract document_type  \
# 0          1  Farhad Manjoo picks four products from 2014 th...       article
# 1          2  Representative Steve Scalise’s effort to expla...       article
# 2          3  Minimum wage increases go into effect in 20 st...       article
# 3          4  A new job title — chief of laboratory safety —...       article
# 4          5  Lawyers for Dzhokhar Tsarnaev, the defendant i...       article
# ...      ...                                                ...           ...
# 50567  50568  The nonsensical catchphrase from a Bud Light a...       article
# 50568  50569  The earthquake of sexual misconduct allegation...       article
# 50569  50570  Artificial intelligence is making it possible ...       article
# 50570  50571  State officials are considering legal challeng...       article
# 50571  50572  A fake report of a hostage situation led to th...       article
#
#                                                 headline  \
# 0      Standouts in Tech: Drones, Virtual Reality, In...
# 1      Much of David Duke’s ’91 Campaign Is Now in Lo...
# 2      States’ Minimum Wages Rise, Helping Millions o...
# 3           New C.D.C. Job Overseeing Laboratory Safety
# 4       Massachusetts: New Effort to Move Bombings Trial
# ...                                                  ...
# 50567  How Do You Turn an Ad Into a Meme? Two Words: ...
# 50568  Partisans, Wielding Money, Begin Seeking to Ex...
# 50569  How Do You Vote? 50 Million Google Images Give...
# 50570  Democrats in High-Tax States Plot to Blunt Imp...
# 50571  Fatal ‘Swatting’ Episode in Kansas Raises Quan...
#
#                                                 keywords  \
# 0      [{'name': 'organizations', 'value': 'Oculus VR...
# 1      [{'name': 'persons', 'value': 'Alford, Jeremy'...
# 2      [{'name': 'subject', 'value': 'Minimum Wage', ...
# 3      [{'name': 'persons', 'value': 'McNeil, Donald ...
# 4      [{'name': 'subject', 'value': 'Boston Marathon...
# ...                                                  ...
# 50567  [{'name': 'subject', 'value': 'ADVERTISING AND...
# 50568  [{'name': 'subject', 'value': 'United States P...
# 50569  [{'name': 'subject', 'value': 'Artificial Inte...
# 50570  [{'name': 'subject', 'value': 'Tax Credits, De...
# 50571  [{'name': 'glocations', 'value': 'Wichita (Kan...
#
#                                           lead_paragraph news_desk  \
# 0      LOTS of cool new technology products come out ...  Business
# 1      BATON ROUGE, La. — David Duke seems a figure f...  National
# 2      For some low-wage workers, everyday tasks like...  Business
# 3      A new job title — chief of laboratory safety —...  National
# 4      Lawyers for Dzhokhar Tsarnaev, the defendant i...  National
# ...                                                  ...       ...
# 50567  In 1995, a nation was rapt as three frogs croa...  Business
# 50568  WASHINGTON — As the #MeToo movement to expose ...  National
# 50569  What vehicle is most strongly associated with ...  Business
# 50570  Democrats in high-cost, high-tax states are pl...  Business
# 50571  When the police surrounded a house in Wichita,...  National
#
#          pub_date  section_name  \
# 0      2015-01-01    Technology
# 1      2015-01-01          U.S.
# 2      2015-01-01  Business Day
# 3      2015-01-01        Health
# 4      2015-01-01          U.S.
# ...           ...           ...
# 50567  2017-12-31  Business Day
# 50568  2017-12-31          U.S.
# 50569  2017-12-31    Technology
# 50570  2017-12-31  Business Day
# 50571  2017-12-31          U.S.
#
#                                                  snippet type_of_material  \
# 0      Farhad Manjoo picks four products from 2014 th...             News
# 1      Representative Steve Scalise’s effort to expla...             News
# 2      Minimum wage increases go into effect in 20 st...             News
# 3      A new job title — chief of laboratory safety —...            Brief
# 4      Lawyers for Dzhokhar Tsarnaev, the defendant i...            Brief
# ...                                                  ...              ...
# 50567  The nonsensical catchphrase from a Bud Light a...             News
# 50568  The earthquake of sexual misconduct allegation...             News
# 50569  Artificial intelligence is making it possible ...             News
# 50570  State officials are considering legal challeng...             News
# 50571  A fake report of a hostage situation led to th...             News
#
#        word_count
# 0             824
# 1            1293
# 2            1017
# 3             129
# 4             145
# ...           ...
# 50567         762
# 50568        1884
# 50569        1191
# 50570        1480
# 50571        1267
#
# [50572 rows x 12 columns]

# %%
# # Convert to CSV, and save cleaned data with 'nid'.

# df.to_csv("../data/files/headlines_with_nid.csv", index=False)

# %% [markdown]
# ### Filter to get relevant data

# %%
df = df.loc[:, ['nid', 'keywords', 'pub_date']]
df
# Out:
#          nid                                           keywords    pub_date
# 0          1  [{'name': 'organizations', 'value': 'Oculus VR...  2015-01-01
# 1          2  [{'name': 'persons', 'value': 'Alford, Jeremy'...  2015-01-01
# 2          3  [{'name': 'subject', 'value': 'Minimum Wage', ...  2015-01-01
# 3          4  [{'name': 'persons', 'value': 'McNeil, Donald ...  2015-01-01
# 4          5  [{'name': 'subject', 'value': 'Boston Marathon...  2015-01-01
# ...      ...                                                ...         ...
# 50567  50568  [{'name': 'subject', 'value': 'ADVERTISING AND...  2017-12-31
# 50568  50569  [{'name': 'subject', 'value': 'United States P...  2017-12-31
# 50569  50570  [{'name': 'subject', 'value': 'Artificial Inte...  2017-12-31
# 50570  50571  [{'name': 'subject', 'value': 'Tax Credits, De...  2017-12-31
# 50571  50572  [{'name': 'glocations', 'value': 'Wichita (Kan...  2017-12-31
#
# [50572 rows x 3 columns]

# %% [markdown]
# ### Extract news locations.

# %%
# Iterate through 'keywords' to extract glocations.

keywords = df["keywords"].to_list()

# Create dictionary for glocations
glocations = {}

for i, e in enumerate(keywords):
    nid = i+1
    for idx, dict in enumerate(e):
        if dict["name"] == "glocations":
            glocations[nid] = dict["value"]
            
print(glocations)
# Out:
# {2: 'Louisiana', 3: 'United States', 5: 'Boston (Mass)', 6: 'Killeen (Tex)', 11: 'East Village (Manhattan, NY)', 12: 'Naples (Fla)', 13: 'Europe', 17: 'Japan', 18: 'Dagestan (Russia)', 21: 'Turkey', 23: 'Las Cruces (NM)', 24: 'Peachtree City (Ga)', 25: 'Boston (Mass)', 35: 'United States', 36: 'Europe', 37: 'Virginia', 39: 'Pennsylvania', 40: 'United States', 42: 'ANTARCTIC REGIONS', 55: 'New Zealand', 56: 'Europe', 59: 'Boston (Mass)', 60: 'Kentucky', 61: 'Michigan', 62: 'Colorado', 72: 'United States', 73: 'Boston (Mass)', 75: 'United States', 76: 'Florida', 89: 'Nebraska', 92: 'United States', 97: 'Louisiana', 99: 'Cape Canaveral (Fla)', 103: 'Vernon (Vt)', 105: 'Pennsylvania', 107: 'Las Vegas (Nev)', 108: 'Boston (Mass)', 111: 'United States', 112: 'France', 113: 'Gilbert (Ariz)', 128: 'Ferguson (Mo)', 129: 'Quebec Province (Canada)', 135: 'Indonesia', 136: 'Iceland', 138: 'Botswana', 140: 'Cambridge (Mass)', 143: 'Wisconsin', 145: 'Europe', 146: 'California', 151: 'ARGENTINA', 154: 'Florida', 155: 'Illinois', 156: 'Europe', 157: 'Mission District (San Francisco, Calif)', 158: 'United States', 159: 'Pennsylvania', 161: 'Guantanamo Bay Naval Base (Cuba)', 162: 'United States', 169: 'Great Britain', 172: 'Virginia', 174: 'Portugal', 183: 'United States', 185: 'Worcester (Mass)', 186: 'Florida', 190: 'United States', 199: 'Houston (Tex)', 200: 'New York City', 203: 'El Paso (Tex)', 204: 'Great Britain', 205: 'United States', 207: 'Atlanta (Ga)', 208: 'Moab (Utah)', 209: 'Ferguson (Mo)', 212: 'Washington (DC)', 213: 'San Francisco (Calif)', 215: 'United States', 219: 'Greece', 224: 'New England States (US)', 225: 'South Carolina', 236: 'United States', 242: 'United States', 243: 'Texas', 244: 'North Korea', 247: 'China', 250: 'Nantucket Sound (Mass)', 251: 'Mississippi', 255: 'Massachusetts', 257: 'California', 258: 'El Paso (Tex)', 260: 'Oklahoma', 262: 'South Korea', 268: 'Rhode Island', 269: 'Hong Kong', 270: 'United States', 271: 'Spain', 279: 'Spain', 284: 'San Francisco (Calif)', 285: 'California', 287: 'United States', 289: 'Vermont', 291: 'Detroit (Mich)', 293: 'London (England)', 294: 'Great Britain', 295: 'Spain', 296: 'Phoenix (Ariz)', 297: 'United States', 298: 'California', 299: 'California', 301: 'Georgia', 304: 'Cleveland (Ohio)', 306: 'Liberia', 312: 'Ohio', 313: 'Kansas', 314: 'Canada', 315: 'West Virginia', 316: 'Greece', 317: 'New York State', 319: 'Colorado Springs (Colo)', 321: 'China', 323: 'South Carolina', 324: 'United States', 326: 'Hong Kong', 327: 'Bermuda', 338: 'United States', 339: 'Nebraska', 343: 'Great Britain', 344: 'Baltimore (Md)', 346: 'United States', 352: 'Las Vegas (Nev)', 354: 'Seattle (Wash)', 361: 'Tennessee', 375: 'Hobbs (NM)', 377: 'South Carolina', 378: 'Middle East', 380: 'Kenya', 381: 'Oklahoma', 382: 'Hyattsville (Md)', 384: 'Nashville (Tenn)', 388: 'Cape Canaveral (Fla)', 390: 'Illinois', 392: 'Florida', 393: 'Florida', 394: 'Baltimore (Md)', 397: 'Philadelphia (Pa)', 413: 'Silicon Valley (Calif)', 416: 'Hong Kong', 418: 'Italy', 420: 'Atlanta (Ga)', 421: 'United States', 427: 'San Francisco (Calif)', 434: 'AMSTERDAM (NETHERLANDS)', 435: 'Dublin (Ireland)', 437: 'Silicon Valley (Calif)', 445: 'London (England)', 446: 'South Carolina', 448: 'China', 449: 'Charlottesville (Va)', 455: 'United States', 460: 'Washington (State)', 466: 'Russia', 468: 'Puerto Rico', 472: 'Gilbert (Ariz)', 478: 'South Sudan', 480: 'ALBUQUERQUE (NM)', 490: 'West Virginia', 494: 'Oklahoma', 495: 'China', 496: 'France', 501: 'Washington (DC)', 502: 'South Carolina', 504: 'Great Britain', 510: 'Aurora (Colo)', 514: 'United States', 515: 'Yemen', 517: 'United States', 518: 'United States', 522: 'Washington (DC)', 524: 'ALABAMA', 526: 'United States', 529: 'United States', 530: 'California', 532: 'California', 536: 'Brooklyn (NYC)', 538: 'New York City', 540: 'Georgia', 543: 'Vermont', 544: 'Detroit (Mich)', 545: 'Detroit (Mich)', 546: 'Detroit (Mich)', 549: 'Washington (State)', 553: 'United States', 554: ' ...

# %%
# Create a dataframe from the dicationary, and add publication dates

my_dict = glocations
df_location = pd.DataFrame(list(my_dict.items()),columns = ['nid','glocation'])
df_location['pub_date'] = " "
df_location = df_location[['nid', 'glocation', 'pub_date']]

# for i in range(len(df_location)):
#     for j in range(len(df)):
#         if df_location['nid'][i] == df['nid'][j]:
#             df_location['pub_date'][i] = df['pub_date'][j]

df_location
# Out:
#          nid                     glocation pub_date
# 0          2                     Louisiana
# 1          3                 United States
# 2          5                 Boston (Mass)
# 3          6                 Killeen (Tex)
# 4         11  East Village (Manhattan, NY)
# ...      ...                           ...      ...
# 16283  50563                 Denver (Colo)
# 16284  50564     Acadia National Park (Me)
# 16285  50570         San Francisco (Calif)
# 16286  50571                New York State
# 16287  50572                 Wichita (Kan)
#
# [16288 rows x 3 columns]

# %%
# # Create dataframe from dict of glocations, then reformat dataframe.

# df_location = pd.DataFrame.from_dict(glocations, orient='index')
# df_location.reset_index(level=0)
# df_location['nid'] = df_location.index
# df_location = df_location.reset_index(drop=True)
# df_location = df_location.rename(columns={df_location.columns[0]:'glocation'})

# df_location['pub_date'] = " "
# df_location = df_location[['nid', 'glocation', 'pub_date']]

for i in range(len(df_location)):
    for j in range(len(df)):
        if df_location['nid'][i] == df['nid'][j]:
            df_location['pub_date'][i] = df['pub_date'][j]

df_location = df_location[['nid', 'glocation', 'pub_date']]
df_location
# Out:
#                                   0
# 2                         Louisiana
# 3                     United States
# 5                     Boston (Mass)
# 6                     Killeen (Tex)
# 11     East Village (Manhattan, NY)
# ...                             ...
# 50563                 Denver (Colo)
# 50564     Acadia National Park (Me)
# 50570         San Francisco (Calif)
# 50571                New York State
# 50572                 Wichita (Kan)
#
# [16288 rows x 1 columns]

# %% [markdown]
# ### News publication dates data

# %%
# Extract year, month and day of week data from publication date. 
df_location['year'] = " "
df_location['month'] = " "
df_location['weekday'] = " "
df_location = df_location[['nid', 'glocation', 'pub_date', 'year', 'month', 'weekday']]  

for i in range(len(df_location)):
    pub_date = datetime.datetime.strptime(df_location.iloc[i, 2], '%Y-%m-%d')
    
    df_location.iloc[i, 3] = pub_date.year
    
    df_location.iloc[i, 4] = pub_date.strftime("%B")  
    
    df_location.iloc[i, 5] = pub_date.strftime("%A")

df_location
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a0fa307f19a1> in <module>
#       1 # Extract year, month and day of week data from publication date.
# ----> 2 df_location['year'] = " "
#       3 df_location['month'] = " "
#       4 df_location['weekday'] = " "
#       5 df_location = df_location[['nid', 'glocation', 'pub_date', 'year', 'month', 'weekday']]
#
# NameError: name 'df_location' is not defined

# %%
# Convert to CSV to save location and dates data with 'nid'.

df_location.to_csv("static/data/choropleth_locations1_clean.csv", index=False)

# %%
# Count of unique glocations
print(df_location['glocation'].nunique())
# Out:
# 1348
